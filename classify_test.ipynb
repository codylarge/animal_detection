# %%
from PytorchWildlife.models import classification as pw_classification

classification_model = pw_classification.DFNE()
print(classification_model.CLASS_NAMES)
# Out:
# ...
# Model loaded from C:\Users\cdlar/.cache\torch\hub\checkpoints\dfne_weights_v1_0.pth
# {0: 'American Marten', 1: 'Bird sp.', 2: 'Black Bear', 3: 'Bobcat', 4: 'Coyote', 5: 'Domestic Cat', 6: 'Domestic Cow', 7: 'Domestic Dog', 8: 'Fisher', 9: 'Gray Fox', 10: 'Gray Squirrel', 11: 'Human', 12: 'Moose', 13: 'Mouse sp.', 14: 'Opossum', 15: 'Raccoon', 16: 'Red Fox', 17: 'Red Squirrel', 18: 'Skunk', 19: 'Snowshoe Hare', 20: 'White-tailed Deer', 21: 'Wild Boar', 22: 'Wild Turkey', 23: 'no-species'}

# %%
from classify import classify_single

primary_dir = "motion_snaps"
secondary_dir = "Unknown_10-47PM_Mar_05_2026"
filename = "motion_1772779637605_zoom.jpg"

path = f"{primary_dir}/{secondary_dir}/{filename}"
classify_single(path, classification_model)
# Out:
# ('Human', 0.5159809589385986)
